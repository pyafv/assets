# %% [markdown]
# ## **PyAFV** usage examples in notebooks
#
# 1. [Getting started](getting_started.ipynb)
# 2. [Active finite Voronoi model](active_dynamics.ipynb)
# 3. [Custom plotting](custom_plot.ipynb)
# 4. [Periodic boundary conditions](periodic_plotting.ipynb)
# 5. [Calibrating with a deformable polygon model](calibration.ipynb)
# 6. [Mimicking Standard Voronoi models](standard_voronoi_sim.ipynb)
