# %% [markdown]
# ## Usage Examples in Notebooks
#
# 1. [Getting started](getting_started.ipynb)
# 2. [Custom plotting](custom_plot.ipynb)
# 3. [Periodic boundary conditions](periodic_plotting.ipynb)
# 4. [Mimicking Standard Voronoi models](standard_voronoi_sim.ipynb)
